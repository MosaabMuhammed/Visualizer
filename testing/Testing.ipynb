# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from utils import *
pd.set_option('display.max_columns', None)

# %%
# df1 = pd.read_csv('/media/mosaab/Volume/Personal/Development/Courses Docs/ML GrandMaster/ml_project/input/train.csv')
# df2 = pd.read_csv('/media/mosaab/Volume/Personal/Development/Courses Docs/ML GrandMaster/ml_project/input/cell2celltrain.csv')
# df3 = pd.read_csv('/media/mosaab/Volume/Personal/Development/Courses Docs/ML GrandMaster/ml_project/input/titanic.csv')
# df4 = pd.read_csv("/media/mosaab/Volume/Personal/Development/Courses Docs/ML GrandMaster/ml_project/input/train_regression.csv")
df = pd.read_csv("/media/mosaab/Volume/Personal/Development/Courses Docs/ML GrandMaster/ml_project/input/new_df.csv")


shape(df)
# Out:
# ~> df      has  2,001     rows, and  18   columns.

# %%
df1_cols = ['bin_3', 'nom_0', 'nom_1', 'nom_5', 'nom_6', 'nom_7', 'nom_8', 'nom_9', 'ord_3', 'ord_5', 'target']
df1.head()
# Out:
#    id  bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2    nom_3  \
# 0   0      0      0      0     T     Y  Green   Triangle    Snake  Finland
# 1   1      0      1      0     T     Y  Green  Trapezoid  Hamster   Russia
# 2   2      0      0      0     F     Y   Blue  Trapezoid     Lion   Russia
# 3   3      0      1      0     F     Y    Red  Trapezoid    Snake   Canada
# 4   4      0      0      0     F     N    Red  Trapezoid     Lion   Canada
#
#       nom_4      nom_5      nom_6      nom_7      nom_8      nom_9  ord_0  \
# 0   Bassoon  50f116bcf  3ac1b8814  68f6ad3e9  c389000ab  2f4cb3d51      2
# 1     Piano  b3b4d25d0  fbcb50fc1  3b6dd5612  4cd920251  f83c56c21      1
# 2  Theremin  3263bdce5  0922e3cb8  a6a36f527  de9c9f684  ae6800dd0      1
# 3      Oboe  f12246592  50d7ad46a  ec69236eb  4ade6ab69  8270f0d71      1
# 4      Oboe  5b0f5acd5  1fe17a1fd  04ddac2be  cb43ab175  b164b72a7      1
#
#          ord_1        ord_2 ord_3 ord_4 ord_5  day  month  target
# ...

# %%
df1.apply(pd.Series.nunique)
# Out:
# id        300000
# bin_0          2
# bin_1          2
# bin_2          2
# bin_3          2
# bin_4          2
# nom_0          3
# nom_1          6
# nom_2          6
# nom_3          6
# nom_4          4
# nom_5        222
# nom_6        522
# nom_7       1220
# nom_8       2215
# nom_9      11981
# ord_0          3
# ord_1          5
# ord_2          6
# ord_3         15
# ord_4         26
# ord_5        192
# day            7
# month         12
# target         2
# dtype: int64

# %%
df2.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  DroppedCalls  BlockedCalls  UnansweredCalls  \
# ...

# %%
df2.apply(pd.Series.nunique)
# Out:
# CustomerID                   51047
# Churn                            2
# MonthlyRevenue               12665
# MonthlyMinutes                2719
# TotalRecurringCharge           214
# DirectorAssistedCalls          146
# OverageMinutes                 746
# RoamingCalls                   530
# PercChangeMinutes             2262
# PercChangeRevenues            2899
# DroppedCalls                   285
# BlockedCalls                   373
# UnansweredCalls                840
# CustomerCareCalls              185
# ThreewayCalls                   78
# ReceivedCalls                 6121
# OutboundCalls                  787
# InboundCalls                   472
# PeakCallsInOut                1839
# OffPeakCallsInOut             1669
# DroppedBlockedCalls            447
# CallForwardingCalls             31
# CallWaitingCalls               223
# MonthsInService                 56
# UniqueSubs                      15
# ActiveSubs                      12
# ServiceArea                    747
# ...

# %%
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df4.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df4_cols = ['SalePrice', 'GarageArea', 'GrLivArea', '1stFlrSF', '1stFlrSF', 'TotalBsmtSF', 'LotArea']

df4.select_dtypes(np.number).columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
new_df = pd.concat([df1.loc[:2000, df1_cols], df4.loc[:2000, df4_cols]], axis=1)

shape(new_df)
# Out:
# ~> new_df  has  2,001     rows, and  18   columns.

# %%
new_df.to_csv("../input/new_df.csv", index=False)

# %%
# 2. Pie Plot: see the distribution from a different way.
sorted_counts = df['target'].value_counts()
# percent = np.round(df[self.target_col].value_counts(normalize=True).values, 3)
patches, texts = plt.pie(sorted_counts, labels=sorted_counts.index, startangle=90,
                         counterclock=False, shadow=True, explode=(0.04, 0), autopct='%1.1f%%')[0:2]
# 
plt.tight_layout()
plt.title('Distribution of Target Labels')
plt.axis('equal');
# plt.savefig(self.path+'/'+self.folder_name+'/target_pie.png', bbox_inches='tight')

# %%
df.select_dtypes('O').apply(pd.Series.nunique)
# Out:
# bin_3        2
# bin_4        2
# nom_0        3
# nom_1        6
# nom_2        6
# nom_3        6
# nom_4        4
# nom_5      222
# nom_6      522
# nom_7     1220
# nom_8     2215
# nom_9    11981
# ord_1        5
# ord_2        6
# ord_3       15
# ord_4       26
# ord_5      192
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
counts = df.nom_6.value_counts().to_dict()
counts
# Out:
# {'d173ac7ca': 1218,
#  '2ed5a94b0': 1210,
#  'c9eedfbc2': 1193,
#  '50d7ad46a': 1175,
#  '0922e3cb8': 1169,
#  'd4d727716': 1167,
#  '705cb7579': 1165,
#  '1fe17a1fd': 1157,
#  '3ac1b8814': 1148,
#  'f497b97d7': 1146,
#  '4f849ad2d': 1140,
#  'bc82e0ba0': 1138,
#  '50e49ea04': 1137,
#  '9448b8e3b': 1137,
#  '71c68195d': 1133,
#  '20636817e': 1133,
#  'a406a5f12': 1125,
#  'bc31d6a6d': 1123,
#  'e16557b2b': 1119,
#  'b238965eb': 1117,
#  '40ac3fcd5': 1116,
#  '642fcc7be': 1114,
#  'a20513779': 1114,
#  'f14fe8bc5': 1113,
#  '017eb57f0': 1113,
#  'cefab1020': 1109,
#  '3b9693870': 1107,
#  'f134870d4': 1102,
#  'cd8e3a0a7': 1101,
#  'c0f1061ee': 1100,
#  'cd94f29d1': 1096,
#  '9e0a099c7': 1095,
#  'edb3cf6c8': 1094,
#  '25d3a1087': 1093,
#  'bb219c9ac': 1091,
#  '718fd9453': 1091,
#  '6046454de': 1086,
#  '42b1cc2fd': 1081,
#  '788ba7aea': 1081,
#  'cf8b12b4e': 1080,
#  'acf5b10dd': 1075,
#  'd213f48ed': 1073,
#  '395941181': 1070,
#  '508ff88dc': 1064,
#  '32be571ee': 1062,
# ...

# %%
plt.figure(figsize=(30, 6))
col_range = range(1, len(counts)+1)
plt.stem(counts.values())
plt.xticks(col_range, list(counts.keys()), rotation=90)
plt.grid()
# len(counts)
# Out:
# /home/mosaab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def show_annotation(dist, n=5, size=14, total=None):
    sizes = []  # Get highest value in y
    for p in dist[2]:
        height = int(p.get_height())
        sizes.append(height)

        plt.text(p.get_x() + p.get_width() / 2.,          # At the center of each bar. (x-axis)
                  height + n,                            # Set the (y-axis)
                  '{:1.2f}%'.format(height * 100 / total) if total else '{}'.format(height),  # Set the text to be written
                  ha='center', fontsize=size)
    plt.ylim(0, max(sizes) * 1.15)  # set y limit based on highest heights

# %%
counts = df.nom_9.value_counts().values
bins = range(counts.min(), counts.max(), int(.05*(counts.max()-counts.min())))
plt.figure(figsize=(12, 6))
ax = plt.hist(counts, edgecolor='k', zorder=3, bins=bins)
plt.grid(zorder=0)
plt.xticks(bins);


sizes = []  # Get highest value in y
for p in ax[2]:
    height = int(p.get_height())
    sizes.append(height)

    plt.text(p.get_x() + p.get_width() / 2.,          # At the center of each bar. (x-axis)
              height + 10,                            # Set the (y-axis)
              '{}'.format(height),  # Set the text to be written
              ha='center', fontsize=12)
plt.ylim(0, max(sizes) * 1.15)  # set y limit based on highest heights
# Out:
# (0, 907.3499999999999)

# %%
  plt.figure(figsize=(25, 6))
  plt.plot(df.bin_0, '.')
  plt.grid()
  plt.xlabel('Row Index')
#   plt.ylabel(f'{col} Values')
#   plt.title(f'Distribution of {col} around row index', y=1.05, size=16)
# Out:
# Text(0.5, 0, 'Row Index')

# %%
df.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
col_name   = 'RoamingCalls'
target_col = 'Occupation'
target     = True

fig = plt.figure(figsize=(25, 6))
ax  = fig.add_axes([0, 0, 1, 1])
if target:
  uniques = df[target_col].unique()
  colors = sns.color_palette(n_colors=len(uniques))
  for i, label in enumerate(uniques):
    ax.plot(df[df[target_col] == label][col_name], lw=1, c=colors[i], label=label)
else: df.plot.line(y=col_name ,figsize=(20,6), lw=1)
plt.grid()
if target: plt.legend()
plt.title(f"Distribution of '{col_name}' along the index", y=1.05, size=16)
plt.ylabel(f'{col_name} values')
plt.xlabel("Row Index")
# Out:
# Text(0.5, 0, 'Row Index')

# %%
import squarify

# %%
import matplotlib as mlt
counts = df.nom_6.value_counts()
cmap = mlt.cm.Blues
mini = min(counts.values)
maxi = max(counts.values)
norm = mlt.colors.Normalize(vmin=mini, vmax=maxi)
colors = [cmap(norm(value)) for value in counts.values]


plt.figure(figsize=(20, 20))
squarify.plot(sizes=counts.values, label=counts.index, alpha=.8, color=colors, text_kwargs={'wrap':True})
plt.axis('off')
plt.show()

# %%
df.apply(pd.Series.nunique)
# Out:
# id        300000
# bin_0          2
# bin_1          2
# bin_2          2
# bin_3          2
# bin_4          2
# nom_0          3
# nom_1          6
# nom_2          6
# nom_3          6
# nom_4          4
# nom_5        222
# nom_6        522
# nom_7       1220
# nom_8       2215
# nom_9      11981
# ord_0          3
# ord_1          5
# ord_2          6
# ord_3         15
# ord_4         26
# ord_5        192
# day            7
# month         12
# target         2
# dtype: int64

# %%
plt.figure(figsize=(14, 8))

ax = sns.countplot(data=df, x='bin_0', hue='target', edgecolor='k', zorder= 3)
plt.grid(zorder=0)
show_annotation(ax, 50, 12, df.shape[0])

# %%
# dfu = df[['bin_0', 'bin_1']].unstack().reset_index()
# dfu.head(20)
col_1 = 'bin_0'
col_2 = 'nom_1'

dfu = pd.crosstab(df[col_1], df[col_2], normalize=True).unstack().reset_index()
dfu.columns = [col_1, col_2, 'counts']
dfu['counts'] *= 10000
mini = int(dfu.counts.min())
maxi = int(dfu.counts.max())
msizes = list(range(mini, maxi, int((maxi-mini)/5)))
markers = []
for size in msizes:
    markers.append(plt.scatter([], [], s=size,
                              label=f'{size}',
                               color='lightgreen',
                              alpha=.6, edgecolor='k', linewidth=1.5))
plt.figure(figsize=(12, 6))
plt.scatter(x=col_1, y=col_2, s='counts', data=dfu, zorder=3, alpha=.8, edgecolor='k', color='lightgreen')
plt.margins(.1)
plt.xlabel(col_1, size=12); plt.ylabel(col_2, size=12)
plt.xticks(dfu[col_1].unique()); plt.yticks(dfu[col_2].unique())
plt.title(f'{col_1} Vs. {col_2}', y=1.05, size=16); plt.grid(zorder=0)
plt.legend(handles=markers, title='Counts',
          labelspacing=3, handletextpad=2,
          fontsize=14, loc=(1.10, .05))
plt.show()

# %%
import operator as op
from functools import reduce

def ncr(n, r):
    r = min(r, n-r)
    numer = reduce(op.mul, range(n, n-r, -1), 1)
    denom = reduce(op.mul, range(1, r+1), 1)
    return numer // denom

# %%
num_1 = 'AgeHH1'
num_2 = 'AgeHH2'
target_col = 'Churn'

plt.figure(figsize=(16, 7))
for label in df[target_col].unique():
    plt.plot(num_1, num_2, data=df[df[target_col] == label], linestyle='', marker='o', markersize=1, alpha=0.05, label=label)
# sns.scatterplot(x=num_1, y=num_2, data=df, zorder=3, hue=target_col)
plt.grid(zorder=0)
plt.title(f"Scatter Plot of '{num_1}' and '{num_2}'", y=1.05, size=16);

# %%
# num_1 = 'MonthlyRevenue'
# num_2 = 'MonthlyMinutes'
# target_col = 'Churn'
# sns.set_style("white")
# sns.kdeplot(df[num_1], df[num_2])#, cmap="Blues", shade=True, shade_lowest=True)
# sns.kdeplot(df[num_1], df[num_2])
sns.jointplot(x=df[num_1], y=df[num_2], kind='kde', cmap="Blues", shade=True, shade_lowest=True)
# plt.title(f'Density between "{num_1}" Vs "{num_2}"', size=14, y=1.05)
# Out:
# Text(0.5, 1.05, 'Density between "AgeHH1" Vs "AgeHH2"')

# %%
df.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  DroppedCalls  BlockedCalls  UnansweredCalls  \
# ...

# %%
df.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  DroppedCalls  BlockedCalls  UnansweredCalls  \
# ...

# %%
sns.boxplot(x='Churn', y='TotalRecurringCharge', data=df)
plt.grid()
plt.title("")
# plt.yscale('log');

# %%
col_name = 'Name'

counts = df[col_name].value_counts().values

# %%
df.head()
# Out:
#   bin_3  nom_0      nom_1      nom_5      nom_6      nom_7      nom_8  \
# 0     T  Green   Triangle  50f116bcf  3ac1b8814  68f6ad3e9  c389000ab
# 1     T  Green  Trapezoid  b3b4d25d0  fbcb50fc1  3b6dd5612  4cd920251
# 2     F   Blue  Trapezoid  3263bdce5  0922e3cb8  a6a36f527  de9c9f684
# 3     F    Red  Trapezoid  f12246592  50d7ad46a  ec69236eb  4ade6ab69
# 4     F    Red  Trapezoid  5b0f5acd5  1fe17a1fd  04ddac2be  cb43ab175
#
#        nom_9 ord_3 ord_5  target  SalePrice  GarageArea  GrLivArea  1stFlrSF  \
# 0  2f4cb3d51     h    kr       0   208500.0       548.0     1710.0     856.0
# 1  f83c56c21     a    bF       0   181500.0       460.0     1262.0    1262.0
# 2  ae6800dd0     h    Jc       0   223500.0       608.0     1786.0     920.0
# 3  8270f0d71     i    kW       1   140000.0       642.0     1717.0     961.0
# 4  b164b72a7     a    qP       0   250000.0       836.0     2198.0    1145.0
#
#    1stFlrSF.1  TotalBsmtSF  LotArea
# 0       856.0        856.0   8450.0
# ...

# %%
cat_col, num_col = 'nom_1', 'GarageArea'

fig = plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x=cat_col, y=num_col, inner='quartile', zorder=10)
plt.xticks(rotation=15)
plt.title(f"{cat_col} Vs. {num_col}", y=1.05, size=20)

# %%
cat_col, num_col = 'bin_3', 'GarageArea'

group_means = df.groupby([cat_col]).mean()
group_order = group_means.sort_values([num_col], ascending=False).index

g = sns.FacetGrid(data=df, row=cat_col, size=0.7, aspect=12, row_order=group_order,
                  gridspec_kws={'hspace': -0.2})
g.map(sns.kdeplot, num_col, shade=True)

g.set(yticks=[])
g.despine(left=True)

# Set the transparency of each subplot to full
g.map(lambda **kwargs: plt.gca().patch.set_alpha(0))

# Remove subplot titles and write in new labels
def label_text(x, **kwargs):
    plt.text(4, 0.0005, x.iloc[0], ha='center', va='bottom')
g.map(label_text, cat_col)
g.set_xlabels(num_col)
g.set_titles('')
# Out:
# /home/mosaab/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /home/mosaab/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:375: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /home/mosaab/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:848: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout()

# %%
group_means = df.groupby([cat_col]).mean()
group_order = group_means.sort_values([num_col], ascending = False).index

# adjust the spacing of subplots with gridspec_kws
g = sns.FacetGrid(data=df, row =cat_col, size=0.5, aspect=12,
                 row_order=group_order, gridspec_kws={'hspace' : -0.001})
g.map(sns.kdeplot, num_col, shade = True)

# remove the y-axes
g.set(yticks=[])
g.despine(left=False)

g.set_titles('{row_name}')
# Out:
# /home/mosaab/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /home/mosaab/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:375: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /home/mosaab/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:848: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout()

# %%
cat_col, num_col = 'nom_1', 'SalePrice'

group_means = df.groupby([cat_col]).mean()
group_order = group_means.sort_values([num_col], ascending = False).index

g = sns.FacetGrid(data = df, row = cat_col, size = 1, aspect = 7,
                 row_order = group_order)
g.map(sns.kdeplot, num_col, shade = True)
g.set_titles('{row_name}')
g.set(yticks=[])
g.despine(left=True)

# %%
df.apply(pd.Series.nunique)
# Out:
# bin_3             2
# nom_0             3
# nom_1             6
# nom_5           209
# nom_6           464
# nom_7           860
# nom_8          1167
# nom_9          1808
# ord_3            15
# ord_5           181
# target            2
# SalePrice       663
# GarageArea      441
# GrLivArea       861
# 1stFlrSF        753
# 1stFlrSF.1      753
# TotalBsmtSF     721
# LotArea        1073
# dtype: int64

# %%
# import pandas
from pandas.plotting import parallel_coordinates

plt.style.use('fivethirtyeight')
sns.set_style('white')

num_cols = ['GarageArea', 'GrLivArea', '1stFlrSF', 'TotalBsmtSF', 'LotArea', 'SalePrice']

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[num_cols])
df_scaled = pd.DataFrame(df_scaled, columns=num_cols)
df_scaled['target'] = df['target']

# Make the plot
plt.figure(figsize=(20, 10))
parallel_coordinates(df_scaled.sample(50), 'target', lw=2, colormap=plt.get_cmap("winter"))
plt.show()

# %%
df.head()
# Out:
#   bin_3  nom_0      nom_1      nom_5      nom_6      nom_7      nom_8  \
# 0     T  Green   Triangle  50f116bcf  3ac1b8814  68f6ad3e9  c389000ab
# 1     T  Green  Trapezoid  b3b4d25d0  fbcb50fc1  3b6dd5612  4cd920251
# 2     F   Blue  Trapezoid  3263bdce5  0922e3cb8  a6a36f527  de9c9f684
# 3     F    Red  Trapezoid  f12246592  50d7ad46a  ec69236eb  4ade6ab69
# 4     F    Red  Trapezoid  5b0f5acd5  1fe17a1fd  04ddac2be  cb43ab175
#
#        nom_9 ord_3 ord_5  target  SalePrice  GarageArea  GrLivArea  1stFlrSF  \
# 0  2f4cb3d51     h    kr       0   208500.0       548.0     1710.0     856.0
# 1  f83c56c21     a    bF       0   181500.0       460.0     1262.0    1262.0
# 2  ae6800dd0     h    Jc       0   223500.0       608.0     1786.0     920.0
# 3  8270f0d71     i    kW       1   140000.0       642.0     1717.0     961.0
# 4  b164b72a7     a    qP       0   250000.0       836.0     2198.0    1145.0
#
#    1stFlrSF.1  TotalBsmtSF  LotArea
# 0       856.0        856.0   8450.0
# ...

# %%
from math import pi
import matplotlib as mlt
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# number of variable
cat_col  = 'ord_5'
num_cols = ['GarageArea', 'GrLivArea', '1stFlrSF', 'TotalBsmtSF', 'LotArea', 'SalePrice']
cat_cols = ['bin_3', 'nom_0', 'nom_1', 'nom_5', 'nom_6', 'nom_7', 'nom_8', 'nom_9', 'ord_3', 'ord_5', 'target']


scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[num_cols])
df_scaled = pd.DataFrame(df_scaled, columns=num_cols)

df_scaled[cat_cols] = df[cat_cols]

grouped_df = df_scaled.groupby(cat_col)[num_cols].mean()
categories = grouped_df[num_cols].columns
N          = len(categories)

values  = grouped_df.iloc[1].values.flatten().tolist()
values += values[:1]
values

angles  = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

mlt.rc('figure', figsize=(8, 8))
ax = plt.subplot(111, polar=True)
plt.xticks(angles[:-1], categories, color='grey', size=13)

# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([.25, .5, .75], [".25", ".5", ".75"], color="grey", size=13)
plt.ylim(0, 1)
ax.plot(angles, values, linewidth=1, linestyle='solid')
ax.fill(angles, values, 'b', alpha=0.1)
plt.title(f"'{cat_col} = ' with num cols")
# Out:
# Text(0.5, 1.0, "'ord_5 = ' with num cols")

# %%
values[:1]
# Out:
# [476.6183098591549]

# %%
df.groupby('bin_3')[num_cols].mean()
# Out:
#        GarageArea    GrLivArea     1stFlrSF  TotalBsmtSF       LotArea  \
# bin_3
# F       476.61831  1512.821127  1163.297183  1054.574648  10232.174648
# T       469.53600  1517.965333  1161.992000  1060.132000  10786.300000
#
#            SalePrice
# bin_3
# F      182123.745070
# T      179782.782667

# %%
# from fastai import *
# from fastai.text import *
import sklearn.feature_extraction.text as sklearn_text
import pickle

# %%
path = untar_data(URLs.IMDB_SAMPLE)
path
# Out:
# ...
# █
# PosixPath('/home/mosaab/.fastai/data/imdb_sample')

# %%
df = pd.read_csv(path/'texts.csv')

df.head()
# Out:
#       label                                               text  is_valid
# 0  negative  Un-bleeping-believable! Meg Ryan doesn't even ...     False
# 1  positive  This is a extremely well-made film. The acting...     False
# 2  negative  Every once in a long while a movie will come a...     False
# 3  positive  Name just says it all. I watched this movie wi...     False
# 4  negative  This movie succeeds at being one of the most u...     False

# %%
movie_reviews = (TextList.from_csv(path, 'texts.csv', cols='text')
                         .split_from_df(col=2)
                         .label_from_df(cols=0))
# Out:
# █

# %%
movie_reviews.valid.x[0]
# Out:
# Text xxbos xxmaj this very funny xxmaj british comedy shows what might happen if a section of xxmaj london , in this case xxmaj xxunk , were to xxunk itself independent from the rest of the xxup uk and its laws , xxunk & post - war xxunk . xxmaj merry xxunk is what would happen .
#
#   xxmaj the explosion of a wartime bomb leads to the xxunk of ancient xxunk which show that xxmaj xxunk was xxunk to the xxmaj xxunk of xxmaj xxunk xxunk ago , a small historical xxunk long since forgotten . xxmaj to the new xxmaj xxunk , however , this is an unexpected opportunity to live as they please , free from any xxunk from xxmaj xxunk .
#
# ...

# %%
movie_reviews.valid.y[1]
# Out:
# Category positive

# %%
movie_reviews.vocab.itos[100], movie_reviews.vocab.stoi['people']
# Out:
# ('people', 100)

# %%
TokenCounter = lambda i: Counter((movie_reviews.train.x)[i].data)
TokenCounter(0).items()
# Out:
# dict_items([(2, 1), (5, 15), (4619, 1), (25, 3), (0, 8), (867, 1), (52, 5), (3776, 1), (1800, 1), (95, 1), (37, 1), (85, 1), (192, 1), (64, 2), (935, 1), (2738, 1), (517, 1), (18, 1), (21, 3), (11, 1), (84, 1), (2417, 1), (193, 1), (88, 1), (3777, 1), (1801, 1), (127, 1), (10, 3), (269, 1), (15, 1), (273, 1), (73, 1), (26, 2), (9, 2), (1360, 1), (35, 2), (1213, 1), (1144, 1), (1145, 1), (2418, 1), (91, 1), (63, 1), (245, 1), (14, 2), (1361, 1), (1447, 1), (65, 1), (40, 1), (796, 1), (103, 1), (72, 2), (99, 1), (534, 1), (616, 1), (48, 1), (282, 1), (54, 1), (90, 1), (219, 1), (228, 1), (43, 1), (13, 1), (3778, 1), (3779, 1), (355, 1), (492, 1)])

# %%
n_terms = len(movie_reviews.vocab.itos)
n_docs  = len(movie_reviewsviews.train.x)
make_token_counter = lambda review_index: Counter(movie_reviews.train.x[review_index].data)

def count_vectorizer(review_index, n_terms=n_terms, make_token_counter=make_token_counter):
# Out:
# array([   2,    5, 4619,   25, ...,   10,    5,    0,   52])

# %%
def make_full_doc_term_matrix(count_vectorizer)
